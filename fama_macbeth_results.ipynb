# %%
# matplotlib inline plotting
# %matplotlib inline
# make inline plotting higher resolution
# %config InlineBackend.figure_format ='svg'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import re
import statsmodels.api as sm
from typing import List
from statsmodels.tsa.ar_model import AutoReg
from itertools import dropwhile

# local imports
from helpers.sql import connect_to_db, update_database, read_db
from helpers.ar_model import transformation, transform, forecast_residual
from helpers.fama_macbeth import FamaMacbeth
from helpers.pretty_print import pretty_print_pval

# %%
# Connect to database (downloads if not exist)
engine = connect_to_db()

# Set this to True to update database locally
update = False

if update:
    update_database()

# %%
# Loading data
factors = read_db(engine=engine, statement="select * from factors", idx_col="date")
risk_free_rate = read_db(
    engine=engine, statement="select * from riskfree", idx_col="date"
)
sentiment = read_db(engine=engine, statement="select * from sentiment", idx_col="date")
returns_bm_size = read_db(
    engine=engine, statement="select * from bm_size_portfolios", idx_col="date"
)
returns_industry_10 = read_db(
    engine=engine, statement='select * from "10_industry_portfolios"', idx_col="date"
)
returns_industry_49 = read_db(
    engine=engine, statement='select * from "49_industry_portfolios"', idx_col="date"
)
sentiment_sum_ar1 = read_db(
    engine=engine, statement="select * from climate_sum_ar1", idx_col="date"
)
sentiment_mean_n_ar1 = read_db(
    engine=engine, statement="select * from climate_mean_n_ar1", idx_col="date"
)

# %%
# Merging into one dataframe
factors_sum = pd.merge(left=factors, right=sentiment_sum_ar1, left_index=True, right_index=True)
factors_mean_n = pd.merge(left=factors, right=sentiment_mean_n_ar1, left_index=True, right_index=True)

# %%
# Subtracting the risk-free rate from the returns
returns_bm_size = pd.merge(
    left=returns_bm_size, right=risk_free_rate, left_index=True, right_index=True
)
returns_bm_size = returns_bm_size.apply(lambda x: x - x["rf"], axis=1)
returns_bm_size = returns_bm_size.drop(columns=["rf"])

returns_industry_10 = pd.merge(
    left=returns_industry_10, right=risk_free_rate, left_index=True, right_index=True
)
returns_industry_10 = returns_industry_10.apply(lambda x: x - x["rf"], axis=1)
returns_industry_10 = returns_industry_10.drop(columns=["rf"])

returns_industry_49 = pd.merge(
    left=returns_industry_49, right=risk_free_rate, left_index=True, right_index=True
)
returns_industry_49 = returns_industry_49.apply(lambda x: x - x["rf"], axis=1)
returns_industry_49 = returns_industry_49.drop(columns=["rf"])

# %%
TOPICS = [
    "aggregate_transformed_residuals",
    "weather_extremes_transformed_residuals",
    "importance_of_human_intervantion_transformed_residuals",
    "politics_transformed_residuals",
]

SIGNIFICANT_DIGITS = 5

# setting newey west lags to 7 according to Greene
# (Econometric Analysis, 7th edition, section 20.5.2, p. 960)
NEWEY_WEST = 7

# there can be some discrepencies in the gmm standard errors when annualising
# this is not the case for the normal fm errors and may be due to some numerical optimisations
# in the gmm
YEARLY_BUSINESS_DAYS: int = 250

START_DATE = '2009-10-13' # first date we have full politics UCP
#START_DATE = "2009-03-02" # the old start date - should not be used (!)
#START_DATE = "2019-09-01"  # Be aware: Large data merge 1. september 2017
END_DATE = "2019-10-01"  # Be aware: Large data merge 1. september 2017

BASE_AP_MODEL = ["mkt-rf", "smb", "hml", "mom"]

# select return observations
returns = {
    "bm_size": returns_bm_size.loc[START_DATE:END_DATE],
    "10_industries": returns_industry_10.loc[START_DATE:END_DATE],
    "49_industries": returns_industry_49.loc[START_DATE:END_DATE],
}

# select factor observations
factors_sum = factors_sum.loc[START_DATE:END_DATE]
factors_mean_n = factors_mean_n.loc[START_DATE:END_DATE]

# %%
# annualise returns
for key, value in returns.items():
    returns[key] = value * YEARLY_BUSINESS_DAYS

# annualise factors
for factor in BASE_AP_MODEL:
    factors_sum[factor] = factors_sum[factor] * YEARLY_BUSINESS_DAYS
    factors_mean_n[factor] = factors_mean_n[factor] * YEARLY_BUSINESS_DAYS

# %%
# remove weekends and holidays from factors
factors_sum = factors_sum.reindex(returns_bm_size.index).dropna(how="all")
factors_mean_n = factors_mean_n.reindex(returns_bm_size.index).dropna(how="all")

# %% [markdown]
# ## Fama Macbeth with sentiment residuals
# This script produces the Fama Macbeth results with residuals.

# %%
def structure_fm_results(fm_res, variant, portfolio_type):
    variants = {
        0: f"I:{portfolio_type}",
        1: f"II:{portfolio_type}",
        2: f"III:{portfolio_type}",
        3: f"IV:{portfolio_type}",
    }

    index = []
    values = []

    for i in fm_res.index:
        # add loading
        index.append(i)
        values.append(fm_res["gamma"].loc[i])

        # add t-stat
        index.append(f"t_{i}")
        values.append(fm_res["tstat_gmm"].loc[i])

    structured = pd.DataFrame(values, index=index, columns=[variants[variant]])

    return structured


def generate_fm_results(
    fac,
    ret,
    portfolios: List[str] = None,
    prettify=True,
    split_forward=False,
    split_backward=False,
    split_date="2014-01-01",
):

    # placeholder for data
    collected = pd.DataFrame()

    # raw fm results
    fm_raw = pd.DataFrame()

    # allow for setting portfolios manually
    if portfolios is None:
        portfolios = ret.keys()

    for portfolio in tqdm(portfolios):
        # placeholder for inner loop
        one_model = pd.DataFrame()

        for i, topic in enumerate(TOPICS):
            # set base factors
            X = fac[BASE_AP_MODEL].copy()
            X[topic] = fac[topic]

            # there is some data missing in 2009 for `importance of human intervation` topic
            # We should probably look into why this is the case
            X = X.dropna()

            # reindex Y (only relevant in case of missing observations in factors
            # i.e. for some sentiment topics
            Y = ret[portfolio].copy().loc[X.index]

            # split sample if needed
            if split_forward and split_backward:
                raise ValueError("Can't split forward and backward at the same time")

            if split_forward:
                X = X.loc[split_date:]
                Y = Y.loc[split_date:]
            if split_backward:
                X = X.loc[:split_date]
                Y = Y.loc[:split_date]

            # estimate and fit FM model
            fm = FamaMacbeth(
                gmm_errors=True,
                n_west_lags=NEWEY_WEST,
                assets=Y,
                factors=X,
            )
            fm.fit()

            # capture results
            fm_fit = fm.summary.copy()
            fm_raw = pd.concat([fm_raw, fm_fit])

            # save additional values
            nobs = fm_fit["nobs"].unique()[0]
            r2 = fm_fit["cs_r2"].unique()[0]

            fm_fit = fm_fit.set_index("gammas", drop=True)
            fm_fit.index.name = None
            fm_fit = fm_fit[["gamma", "tstat_gmm"]]

            # structure results
            if one_model.shape == (0, 0):
                one_model = structure_fm_results(fm_fit, i, portfolio)
                one_model[f"sort_{i}"] = [i for i in range(one_model.shape[0])]
                one_model.loc["nobs"] = nobs
                one_model.loc["r2"] = r2
                continue
                # break

            else:
                struct = structure_fm_results(fm_fit, i, portfolio)
                struct[f"sort_{i}"] = [i for i in range(struct.shape[0])]
                struct.loc["nobs"] = nobs
                struct.loc["r2"] = r2

                one_model = pd.merge(
                    left=one_model,
                    right=struct,
                    how="outer",
                    left_index=True,
                    right_index=True,
                )

        # fix weird sorting. This is a major hack that I needed to implement
        # as "outer" joins do not preserve the order of the index
        sort_cols = [f"sort_{i}" for i in range(len(TOPICS))]
        one_model = one_model.sort_values(by=sort_cols).drop(columns=sort_cols)

        if collected.shape == (0, 0):
            collected = one_model
            continue
        else:
            collected = pd.merge(
                left=collected,
                right=one_model,
                how="left",
                left_index=True,
                right_index=True,
            )

    # yet another hack to move r2 and nobs to the bottom of dataframe
    # store r2 and nobs in separate dataframe
    r2_nobs = collected.loc[["r2", "nobs"]]
    # drop r2 and nobs from collected
    collected = collected.drop(index=["r2", "nobs"])
    # concat r2 and nobs to collected
    collected = pd.concat([collected, r2_nobs])

    return collected, fm_raw

# %%
fm_results_sum = generate_fm_results(
    factors_sum, returns, portfolios=["bm_size", "49_industries"]
)

fm_results_mean_n = generate_fm_results(
    factors_mean_n, returns, portfolios=["bm_size", "49_industries"]
)


# Forwards for the Sum and Mean_N measure
fm_results_forward_sum = generate_fm_results(
    factors_sum,
    returns,
    split_forward=True,
    split_backward=False,
    split_date="2014-01-01",
    portfolios=["bm_size", "49_industries"],
)

fm_results_forward_mean_n = generate_fm_results(
    factors_mean_n,
    returns,
    split_forward=True,
    split_backward=False,
    split_date="2014-01-01",
    portfolios=["bm_size", "49_industries"],
)


# Backwards for the Sum and Mean_N measure
fm_results_backward_sum = generate_fm_results(
    factors_sum,
    returns,
    split_forward=False,
    split_backward=True,
    split_date="2014-01-01",
    portfolios=["bm_size", "49_industries"],
)

fm_results_backward_mean_n = generate_fm_results(
    factors_mean_n,
    returns,
    split_forward=False,
    split_backward=True,
    split_date="2014-01-01",
    portfolios=["bm_size", "49_industries"],
)
# Out:
# 100%|██████████| 2/2 [05:03<00:00, 151.83s/it]
# 100%|██████████| 2/2 [04:59<00:00, 149.60s/it]
# 100%|██████████| 2/2 [01:35<00:00, 47.51s/it]
# 100%|██████████| 2/2 [01:34<00:00, 47.20s/it]
# 100%|██████████| 2/2 [00:51<00:00, 25.59s/it]
# 100%|██████████| 2/2 [00:50<00:00, 25.40s/it]

# %%
print("Sum")
display(fm_results_sum[0])

print("Mean")
display(fm_results_mean_n[0])

print("Forward - Sum")
display(fm_results_forward_sum[0])

print("Forward - Mean")
display(fm_results_forward_mean_n[0])

print("Backward - Sum")
display(fm_results_backward_sum[0])

print("Backward - Mean")
display(fm_results_backward_mean_n[0])
# Out:
# Sum
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.075570     0.103317
# t_c                                                    0.995026     1.131778
# mkt-rf                                                 0.059129     0.028833
# t_mkt-rf                                               0.670622     0.285526
# smb                                                   -0.020335    -0.015913
# t_smb                                                 -0.771370    -0.608143
# hml                                                   -0.034649    -0.034750
# t_hml                                                 -1.331683    -1.323701
# mom                                                    0.175036     0.186120
# t_mom                                                  1.166196     1.096582
# aggregate_transformed_residuals                        0.212989          NaN
# t_aggregate_transformed_residuals                      0.167715          NaN
# weather_extremes_transformed_residuals                      NaN     1.416562
# t_weather_extremes_transformed_residuals                    NaN     1.539898
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.480445     0.585031
# nobs                                                2491.000000  2491.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.080470     0.085773
# t_c                                                    0.974608     0.959030
# mkt-rf                                                 0.055094     0.047197
# t_mkt-rf                                               0.581904     0.472897
# smb                                                   -0.020836    -0.017434
# t_smb                                                 -0.790405    -0.659740
# hml                                                   -0.037384    -0.037039
# t_hml                                                 -1.433895    -1.433491
# mom                                                    0.161536     0.166670
# t_mom                                                  1.070426     0.993063
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...     0.870594          NaN
# t_importance_of_human_intervantion_transformed_...     1.407837          NaN
# politics_transformed_residuals                              NaN    -1.334234
# t_politics_transformed_residuals                            NaN    -1.617983
# r2                                                     0.545083     0.619836
# nobs                                                2491.000000  2491.000000
#
#                                                     I:49_industries  \
# c                                                          0.073082
# t_c                                                        1.027187
# mkt-rf                                                     0.065215
# t_mkt-rf                                                   0.756638
# smb                                                       -0.000786
# t_smb                                                     -0.019158
# hml                                                       -0.035954
# t_hml                                                     -1.139742
# mom                                                        0.296699
# t_mom                                                      2.600492
# aggregate_transformed_residuals                           -0.366374
# t_aggregate_transformed_residuals                         -0.553031
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.872997
# nobs                                                    2491.000000
#
#                                                     II:49_industries  \
# c                                                           0.068780
# t_c                                                         1.013428
# mkt-rf                                                      0.068792
# t_mkt-rf                                                    0.819183
# smb                                                        -0.003219
# t_smb                                                      -0.082080
# hml                                                        -0.036583
# t_hml                                                      -1.166436
# mom                                                         0.296447
# t_mom                                                       2.613997
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.238086
# t_weather_extremes_transformed_residuals                   -0.567890
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.872312
# nobs                                                     2491.000000
#
#                                                     III:49_industries  \
# c                                                            0.064487
# t_c                                                          0.986403
# mkt-rf                                                       0.073190
# t_mkt-rf                                                     0.889437
# smb                                                         -0.005367
# t_smb                                                       -0.134492
# hml                                                         -0.037960
# t_hml                                                       -1.224607
# mom                                                          0.295101
# t_mom                                                        2.563009
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...           0.023273
# t_importance_of_human_intervantion_transformed_...           0.048538
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.868884
# nobs                                                      2491.000000
#
#                                                     IV:49_industries
# c                                                           0.063746
# t_c                                                         0.941917
# mkt-rf                                                      0.073910
# t_mkt-rf                                                    0.881874
# smb                                                        -0.004817
# t_smb                                                      -0.125372
# hml                                                        -0.038190
# t_hml                                                      -1.209948
# mom                                                         0.294765
# t_mom                                                       2.698215
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                              0.044898
# t_politics_transformed_residuals                            0.078742
# r2                                                          0.868943
# nobs                                                     2491.000000
# Mean
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.097371     0.082629
# t_c                                                    1.156698     1.040098
# mkt-rf                                                 0.036482     0.051788
# t_mkt-rf                                               0.389535     0.568463
# smb                                                   -0.017074    -0.019872
# t_smb                                                 -0.653356    -0.756714
# hml                                                   -0.034975    -0.035157
# t_hml                                                 -1.355012    -1.347833
# mom                                                    0.091010     0.160790
# t_mom                                                  0.532809     1.085920
# aggregate_transformed_residuals                       -0.198687          NaN
# t_aggregate_transformed_residuals                     -1.387201          NaN
# weather_extremes_transformed_residuals                      NaN     0.084017
# t_weather_extremes_transformed_residuals                    NaN     0.867473
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.539633     0.491310
# nobs                                                2491.000000  2491.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.079434     0.137923
# t_c                                                    1.049305     1.318525
# mkt-rf                                                 0.054989    -0.004281
# t_mkt-rf                                               0.622678    -0.037551
# smb                                                   -0.019881    -0.014319
# t_smb                                                 -0.755972    -0.541153
# hml                                                   -0.033989    -0.040493
# t_hml                                                 -1.305148    -1.572006
# mom                                                    0.162175     0.108392
# t_mom                                                  1.114138     0.576421
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...    -0.027328          NaN
# t_importance_of_human_intervantion_transformed_...    -0.201557          NaN
# politics_transformed_residuals                              NaN    -0.444004
# t_politics_transformed_residuals                            NaN    -2.092137
# r2                                                     0.480503     0.773197
# nobs                                                2491.000000  2491.000000
#
#                                                     I:49_industries  \
# c                                                          0.065962
# t_c                                                        0.969582
# mkt-rf                                                     0.072250
# t_mkt-rf                                                   0.863109
# smb                                                       -0.003902
# t_smb                                                     -0.097855
# hml                                                       -0.036189
# t_hml                                                     -1.140280
# mom                                                        0.296471
# t_mom                                                      2.617613
# aggregate_transformed_residuals                           -0.022151
# t_aggregate_transformed_residuals                         -0.224191
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.869853
# nobs                                                    2491.000000
#
#                                                     II:49_industries  \
# c                                                           0.065234
# t_c                                                         0.984727
# mkt-rf                                                      0.072121
# t_mkt-rf                                                    0.870051
# smb                                                        -0.005818
# t_smb                                                      -0.151507
# hml                                                        -0.036791
# t_hml                                                      -1.165031
# mom                                                         0.296174
# t_mom                                                       2.607971
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.039465
# t_weather_extremes_transformed_residuals                   -0.548993
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.873184
# nobs                                                     2491.000000
#
#                                                     III:49_industries  \
# c                                                            0.063975
# t_c                                                          0.978682
# mkt-rf                                                       0.073751
# t_mkt-rf                                                     0.891537
# smb                                                         -0.005206
# t_smb                                                       -0.129959
# hml                                                         -0.038114
# t_hml                                                       -1.223459
# mom                                                          0.295584
# t_mom                                                        2.675175
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...           0.000787
# t_importance_of_human_intervantion_transformed_...           0.006663
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.868861
# nobs                                                      2491.000000
#
#                                                     IV:49_industries
# c                                                           0.064029
# t_c                                                         0.979167
# mkt-rf                                                      0.074360
# t_mkt-rf                                                    0.911145
# smb                                                        -0.007027
# t_smb                                                      -0.184878
# hml                                                        -0.038854
# t_hml                                                      -1.224063
# mom                                                         0.294893
# t_mom                                                       2.580788
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                             -0.030487
# t_politics_transformed_residuals                           -0.264022
# r2                                                          0.870850
# nobs                                                     2491.000000
# Forward - Sum
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.037565     0.078020
# t_c                                                    0.441860     0.867728
# mkt-rf                                                 0.077121     0.033311
# t_mkt-rf                                               0.753714     0.319527
# smb                                                   -0.050832    -0.047713
# t_smb                                                 -1.428275    -1.354702
# hml                                                   -0.047359    -0.042701
# t_hml                                                 -1.274111    -1.141775
# mom                                                    0.179195     0.172004
# t_mom                                                  1.566289     1.346361
# aggregate_transformed_residuals                        1.061564          NaN
# t_aggregate_transformed_residuals                      0.915752          NaN
# weather_extremes_transformed_residuals                      NaN     1.038215
# t_weather_extremes_transformed_residuals                    NaN     1.223262
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.743737     0.780651
# nobs                                                1438.000000  1438.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.033346     0.045524
# t_c                                                    0.376683     0.532205
# mkt-rf                                                 0.080312     0.068513
# t_mkt-rf                                               0.766897     0.685948
# smb                                                   -0.047699    -0.050798
# t_smb                                                 -1.362204    -1.426511
# hml                                                   -0.050354    -0.045414
# t_hml                                                 -1.358371    -1.228281
# mom                                                    0.174249     0.191381
# t_mom                                                  1.524439     1.670692
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...     1.006291          NaN
# t_importance_of_human_intervantion_transformed_...     1.178406          NaN
# politics_transformed_residuals                              NaN    -0.880774
# t_politics_transformed_residuals                            NaN    -1.236998
# r2                                                     0.794609     0.764083
# nobs                                                1438.000000  1438.000000
#
#                                                     I:49_industries  \
# c                                                          0.073147
# t_c                                                        0.898251
# mkt-rf                                                     0.040160
# t_mkt-rf                                                   0.420183
# smb                                                       -0.034547
# t_smb                                                     -0.669608
# hml                                                       -0.062310
# t_hml                                                     -1.385265
# mom                                                        0.174473
# t_mom                                                      1.449742
# aggregate_transformed_residuals                           -0.889753
# t_aggregate_transformed_residuals                         -1.032235
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.758950
# nobs                                                    1438.000000
#
#                                                     II:49_industries  \
# c                                                           0.070899
# t_c                                                         0.929195
# mkt-rf                                                      0.039156
# t_mkt-rf                                                    0.421378
# smb                                                        -0.036581
# t_smb                                                      -0.722878
# hml                                                        -0.064959
# t_hml                                                      -1.446968
# mom                                                         0.174313
# t_mom                                                       1.499434
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.425165
# t_weather_extremes_transformed_residuals                   -0.872169
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.733936
# nobs                                                     1438.000000
#
#                                                     III:49_industries  \
# c                                                            0.065185
# t_c                                                          0.864259
# mkt-rf                                                       0.046263
# t_mkt-rf                                                     0.498522
# smb                                                         -0.035728
# t_smb                                                       -0.695823
# hml                                                         -0.072625
# t_hml                                                       -1.618418
# mom                                                          0.169497
# t_mom                                                        1.450605
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...          -0.283679
# t_importance_of_human_intervantion_transformed_...          -0.428697
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.724134
# nobs                                                      1438.000000
#
#                                                     IV:49_industries
# c                                                           0.090718
# t_c                                                         1.081068
# mkt-rf                                                      0.021622
# t_mkt-rf                                                    0.218705
# smb                                                        -0.037231
# t_smb                                                      -0.725806
# hml                                                        -0.068926
# t_hml                                                      -1.516005
# mom                                                         0.178560
# t_mom                                                       1.536746
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                             -0.541186
# t_politics_transformed_residuals                           -0.790961
# r2                                                          0.732193
# nobs                                                     1438.000000
# Forward - Mean
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.035783     0.054456
# t_c                                                    0.452735     0.669746
# mkt-rf                                                 0.078207     0.058917
# t_mkt-rf                                               0.821721     0.601361
# smb                                                   -0.050404    -0.050616
# t_smb                                                 -1.430326    -1.421741
# hml                                                   -0.044062    -0.044764
# t_hml                                                 -1.186021    -1.200176
# mom                                                    0.167572     0.157913
# t_mom                                                  1.520320     1.303081
# aggregate_transformed_residuals                       -0.031236          NaN
# t_aggregate_transformed_residuals                     -0.237948          NaN
# weather_extremes_transformed_residuals                      NaN     0.157411
# t_weather_extremes_transformed_residuals                    NaN     1.363909
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.732403     0.754484
# nobs                                                1438.000000  1438.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.033974     0.073163
# t_c                                                    0.435027     0.834921
# mkt-rf                                                 0.079926     0.039578
# t_mkt-rf                                               0.847524     0.387796
# smb                                                   -0.050512    -0.048572
# t_smb                                                 -1.422970    -1.364013
# hml                                                   -0.043719    -0.047203
# t_hml                                                 -1.175645    -1.275882
# mom                                                    0.166759     0.175921
# t_mom                                                  1.504946     1.486481
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...    -0.030714          NaN
# t_importance_of_human_intervantion_transformed_...    -0.177441          NaN
# politics_transformed_residuals                              NaN    -0.254142
# t_politics_transformed_residuals                            NaN    -1.726753
# r2                                                     0.732064     0.803203
# nobs                                                1438.000000  1438.000000
#
#                                                     I:49_industries  \
# c                                                          0.067425
# t_c                                                        0.862952
# mkt-rf                                                     0.046807
# t_mkt-rf                                                   0.509101
# smb                                                       -0.040273
# t_smb                                                     -0.788135
# hml                                                       -0.057109
# t_hml                                                     -1.259885
# mom                                                        0.165804
# t_mom                                                      1.369760
# aggregate_transformed_residuals                           -0.113200
# t_aggregate_transformed_residuals                         -1.020584
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.761742
# nobs                                                    1438.000000
#
#                                                     II:49_industries  \
# c                                                           0.069499
# t_c                                                         0.909068
# mkt-rf                                                      0.040374
# t_mkt-rf                                                    0.430971
# smb                                                        -0.037985
# t_smb                                                      -0.755018
# hml                                                        -0.067817
# t_hml                                                      -1.517342
# mom                                                         0.174502
# t_mom                                                       1.509831
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.047569
# t_weather_extremes_transformed_residuals                   -0.561542
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.725679
# nobs                                                     1438.000000
#
#                                                     III:49_industries  \
# c                                                            0.073729
# t_c                                                          0.939303
# mkt-rf                                                       0.036996
# t_mkt-rf                                                     0.389930
# smb                                                         -0.035395
# t_smb                                                       -0.683828
# hml                                                         -0.072797
# t_hml                                                       -1.624501
# mom                                                          0.166789
# t_mom                                                        1.516642
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...          -0.028566
# t_importance_of_human_intervantion_transformed_...          -0.249962
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.720363
# nobs                                                      1438.000000
#
#                                                     IV:49_industries
# c                                                           0.085323
# t_c                                                         1.032611
# mkt-rf                                                      0.028831
# t_mkt-rf                                                    0.300879
# smb                                                        -0.043515
# t_smb                                                      -0.851862
# hml                                                        -0.067076
# t_hml                                                      -1.484347
# mom                                                         0.176100
# t_mom                                                       1.491488
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                             -0.121320
# t_politics_transformed_residuals                           -1.002443
# r2                                                          0.766498
# nobs                                                     1438.000000
# Backward - Sum
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.085208     0.096464
# t_c                                                    0.665130     0.805089
# mkt-rf                                                 0.075077     0.065102
# t_mkt-rf                                               0.461314     0.417879
# smb                                                    0.025923     0.026370
# t_smb                                                  0.670394     0.678736
# hml                                                   -0.025660    -0.026755
# t_hml                                                 -0.732150    -0.768781
# mom                                                    0.144813     0.151315
# t_mom                                                  1.123756     1.219734
# aggregate_transformed_residuals                        0.953613          NaN
# t_aggregate_transformed_residuals                      1.175105          NaN
# weather_extremes_transformed_residuals                      NaN     0.145815
# t_weather_extremes_transformed_residuals                    NaN     0.194692
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.424730     0.377703
# nobs                                                1053.000000  1053.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.108107     0.120126
# t_c                                                    0.912029     0.938520
# mkt-rf                                                 0.052771     0.042821
# t_mkt-rf                                               0.344967     0.262764
# smb                                                    0.027389     0.027355
# t_smb                                                  0.708143     0.707002
# hml                                                   -0.024681    -0.029552
# t_hml                                                 -0.712157    -0.848522
# mom                                                    0.138692     0.132380
# t_mom                                                  1.213755     1.053237
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...    -0.167091          NaN
# t_importance_of_human_intervantion_transformed_...    -0.438830          NaN
# politics_transformed_residuals                              NaN    -0.406513
# t_politics_transformed_residuals                            NaN    -1.013897
# r2                                                     0.383106     0.399579
# nobs                                                1053.000000  1053.000000
#
#                                                     I:49_industries  \
# c                                                          0.178269
# t_c                                                        1.499700
# mkt-rf                                                    -0.014682
# t_mkt-rf                                                  -0.094935
# smb                                                        0.040716
# t_smb                                                      0.658192
# hml                                                        0.022066
# t_hml                                                      0.477546
# mom                                                        0.448131
# t_mom                                                      3.695898
# aggregate_transformed_residuals                           -0.777176
# t_aggregate_transformed_residuals                         -1.135425
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.591600
# nobs                                                    1053.000000
#
#                                                     II:49_industries  \
# c                                                           0.143601
# t_c                                                         1.336132
# mkt-rf                                                      0.020585
# t_mkt-rf                                                    0.141600
# smb                                                         0.028338
# t_smb                                                       0.467937
# hml                                                         0.023668
# t_hml                                                       0.521288
# mom                                                         0.450413
# t_mom                                                       3.713115
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.223070
# t_weather_extremes_transformed_residuals                   -0.510520
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.554653
# nobs                                                     1053.000000
#
#                                                     III:49_industries  \
# c                                                            0.117397
# t_c                                                          1.080112
# mkt-rf                                                       0.047823
# t_mkt-rf                                                     0.326667
# smb                                                          0.015114
# t_smb                                                        0.246398
# hml                                                          0.030477
# t_hml                                                        0.679167
# mom                                                          0.438329
# t_mom                                                        3.648089
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...           0.243475
# t_importance_of_human_intervantion_transformed_...           0.832701
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.569132
# nobs                                                      1053.000000
#
#                                                     IV:49_industries
# c                                                           0.140882
# t_c                                                         1.217406
# mkt-rf                                                      0.024056
# t_mkt-rf                                                    0.157652
# smb                                                         0.023911
# t_smb                                                       0.390434
# hml                                                         0.025193
# t_hml                                                       0.536879
# mom                                                         0.449077
# t_mom                                                       3.660768
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                              0.124253
# t_politics_transformed_residuals                            0.357787
# r2                                                          0.553387
# nobs                                                     1053.000000
# Backward - Mean
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.081427     0.066194
# t_c                                                    0.577288     0.487421
# mkt-rf                                                 0.077307     0.094061
# t_mkt-rf                                               0.446692     0.556847
# smb                                                    0.025536     0.028800
# t_smb                                                  0.660928     0.744081
# hml                                                   -0.023734    -0.027421
# t_hml                                                 -0.673554    -0.774560
# mom                                                    0.192133     0.134295
# t_mom                                                  1.299248     1.061789
# aggregate_transformed_residuals                        0.158284          NaN
# t_aggregate_transformed_residuals                      1.699591          NaN
# weather_extremes_transformed_residuals                      NaN     0.127603
# t_weather_extremes_transformed_residuals                    NaN     1.142212
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.509578     0.446138
# nobs                                                1053.000000  1053.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.098533     0.127691
# t_c                                                    0.840596     0.960186
# mkt-rf                                                 0.063465     0.036830
# t_mkt-rf                                               0.415865     0.220060
# smb                                                    0.025519     0.026382
# t_smb                                                  0.660486     0.681015
# hml                                                   -0.026659    -0.028607
# t_hml                                                 -0.768859    -0.827487
# mom                                                    0.150322     0.132323
# t_mom                                                  1.235646     1.063590
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...     0.013794          NaN
# t_importance_of_human_intervantion_transformed_...     0.139349          NaN
# politics_transformed_residuals                              NaN    -0.134420
# t_politics_transformed_residuals                            NaN    -1.136884
# r2                                                     0.377166     0.409338
# nobs                                                1053.000000  1053.000000
#
#                                                     I:49_industries  \
# c                                                          0.158699
# t_c                                                        1.419875
# mkt-rf                                                     0.004448
# t_mkt-rf                                                   0.029712
# smb                                                        0.037090
# t_smb                                                      0.612959
# hml                                                        0.026532
# t_hml                                                      0.578410
# mom                                                        0.459383
# t_mom                                                      3.769310
# aggregate_transformed_residuals                           -0.061800
# t_aggregate_transformed_residuals                         -0.912687
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.568492
# nobs                                                    1053.000000
#
#                                                     II:49_industries  \
# c                                                           0.139098
# t_c                                                         1.254158
# mkt-rf                                                      0.025262
# t_mkt-rf                                                    0.169946
# smb                                                         0.024004
# t_smb                                                       0.400269
# hml                                                         0.021924
# t_hml                                                       0.486092
# mom                                                         0.454299
# t_mom                                                       3.710974
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.031869
# t_weather_extremes_transformed_residuals                   -0.512198
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.554532
# nobs                                                     1053.000000
#
#                                                     III:49_industries  \
# c                                                            0.097405
# t_c                                                          0.893673
# mkt-rf                                                       0.069204
# t_mkt-rf                                                     0.474903
# smb                                                          0.003782
# t_smb                                                        0.060278
# hml                                                          0.035150
# t_hml                                                        0.768454
# mom                                                          0.403737
# t_mom                                                        3.420558
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...           0.128133
# t_importance_of_human_intervantion_transformed_...           1.220969
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.604770
# nobs                                                      1053.000000
#
#                                                     IV:49_industries
# c                                                           0.110403
# t_c                                                         1.026365
# mkt-rf                                                      0.052710
# t_mkt-rf                                                    0.363337
# smb                                                         0.020216
# t_smb                                                       0.337945
# hml                                                         0.020384
# t_hml                                                       0.449034
# mom                                                         0.454891
# t_mom                                                       3.758200
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                             -0.072335
# t_politics_transformed_residuals                           -0.787243
# r2                                                          0.560414
# nobs                                                     1053.000000

# %%
def map_results(coef, prepend="gamma"):
    mapper = {
        "c": r"\multirow{{2}}{{*}}{{$\widehat{{\{}_{{0}}}}$}}".format(prepend),
        "t_c": np.nan,

        "mkt-rf": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{mkt-rf}}$}}".format(prepend),
        "t_mkt-rf": np.nan,

        "smb": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{smb}}$}}".format(prepend),
        "t_smb": np.nan,

        "hml": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{hml}}$}}".format(prepend),
        "t_hml": np.nan,

        "mom": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{mom}}$}}".format(prepend),
        "t_mom": np.nan,

        "aggregate": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{agg}}$}}".format(prepend),
        "t_aggregate": np.nan,

        "weather_extremes": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{wea}}$}}".format(prepend),
        "t_weather_extremes": np.nan,

        "importance_of_human_intervantion": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{imp}}$}}".format(prepend),
        "t_importance_of_human_intervantion": np.nan,
        
        "politics": r"\multirow{{2}}{{*}}{{$\widehat{{\{}}}_{{pol}}$}}".format(prepend),
        "t_politics": np.nan,

        "r2": r"$R^2$",
        "nobs": r"$N$",
    }

    return mapper.get(coef)


def prettify_fm_results(df):
    coll_df = df.copy()

    # apply multiindex to columns and split on portfolio type
    arrays = [
        coll_df.columns.map(lambda x: x.split(":")[1]),
        coll_df.columns.map(lambda x: x.split(":")[0]),
    ]
    tuples = list(zip(*arrays))

    coll_df.columns = pd.MultiIndex.from_tuples(tuples)

    # add parenthesis to t-stat
    for row in coll_df.loc[coll_df.index.str.contains(rf"t_")].index:
        coll_df.loc[row] = (
            coll_df.loc[row]
            .apply(
                pretty_print_pval, freedom=coll_df.loc['nobs'].min(), precision=SIGNIFICANT_DIGITS
            )
            .astype(str)
            .mask(coll_df.loc[row].isna())
        )

    # map index to remove _transformed_residuals
    coll_df.index = coll_df.index.map(lambda x: x.replace("_transformed_residuals", ""))

    # pretty print results
    coll_df = coll_df.rename(columns={
        "bm_size": r"\textbf{25 Book-to-Market and Size Sorted Portfolios}",
        "49_industries": r"\textbf{49 Industry Portfolios}"
    })

    coll_df.loc['nobs'] = (
            coll_df.loc['nobs']
            .apply(
                lambda x: f"{round(x, 0):.{0}f}"
            )
            .astype(str)
            .mask(coll_df.loc['nobs'].isna())
        )

    return coll_df


def print_latex_table(df, map_rows: bool=True, prettify: bool = True, **kwargs):
    print_df = df.copy()

    if prettify:
        print_df = prettify_fm_results(print_df)

    if map_rows:
        print_df.index = print_df.index.map(map_results)

    latex = print_df.to_latex(
        index=True,
        escape=False,
        sparsify=True,
        multirow=True,
        multicolumn=True,
        na_rep="",
        multicolumn_format="c",
        float_format=f"{{:.{SIGNIFICANT_DIGITS}f}}".format,
        position="H",
        **kwargs
    )

    latex = re.sub(r"\\(mid|top|bottom)rule", "", latex)

    # remove empty lines
    latex = latex.replace("NaN", "")

    print(latex)

    return

# %%
print("Sum - full sample \n\n")

print_latex_table(fm_results_sum[0], bold_rows = False)
# Out:
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(
# Sum - full sample
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &              IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.07557 &         0.10332 &         0.08047 &         0.08577 &                         0.07308 &          0.06878 &          0.06449 &          0.06375 \\
#                                           &                                          (0.99503) &       (1.13178) &       (0.97461) &       (0.95903) &                       (1.02719) &        (1.01343) &        (0.98640) &        (0.94192) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.05913 &         0.02883 &         0.05509 &         0.04720 &                         0.06521 &          0.06879 &          0.07319 &          0.07391 \\
#                                           &                                          (0.67062) &       (0.28553) &       (0.58190) &       (0.47290) &                       (0.75664) &        (0.81918) &        (0.88944) &        (0.88187) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.02033 &        -0.01591 &        -0.02084 &        -0.01743 &                        -0.00079 &         -0.00322 &         -0.00537 &         -0.00482 \\
#                                           &                                         (-0.77137) &      (-0.60814) &      (-0.79041) &      (-0.65974) &                      (-0.01916) &       (-0.08208) &       (-0.13449) &       (-0.12537) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.03465 &        -0.03475 &        -0.03738 &        -0.03704 &                        -0.03595 &         -0.03658 &         -0.03796 &         -0.03819 \\
#                                           &                                     (-1.33168) (*) &  (-1.32370) (*) &  (-1.43389) (*) &  (-1.43349) (*) &                      (-1.13974) &       (-1.16644) &       (-1.22461) &       (-1.20995) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.17504 &         0.18612 &         0.16154 &         0.16667 &                         0.29670 &          0.29645 &          0.29510 &          0.29476 \\
#                                           &                                          (1.16620) &       (1.09658) &       (1.07043) &       (0.99306) &                 (2.60049) (***) &  (2.61400) (***) &  (2.56301) (***) &  (2.69822) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                            0.21299 &                 &                 &                 &                        -0.36637 &                  &                  &                  \\
#                                           &                                          (0.16772) &                 &                 &                 &                      (-0.55303) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &         1.41656 &                 &                 &                                 &         -0.23809 &                  &                  \\
#                                           &                                                    &   (1.53990) (*) &                 &                 &                                 &       (-0.56789) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &         0.87059 &                 &                                 &                  &          0.02327 &                  \\
#                                           &                                                    &                 &   (1.40784) (*) &                 &                                 &                  &        (0.04854) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &        -1.33423 &                                 &                  &                  &          0.04490 \\
#                                           &                                                    &                 &                 &  (-1.61798) (*) &                                 &                  &                  &        (0.07874) \\
# $R^2$                                        &                                            0.48045 &         0.58503 &         0.54508 &         0.61984 &                         0.87300 &          0.87231 &          0.86888 &          0.86894 \\
# $N$                                          &                                               2491 &            2491 &            2491 &            2491 &                            2491 &             2491 &             2491 &             2491 \\
#
# \end{tabular}
# \end{table}

# %%
print("Mean N - full sample \n\n")

print_latex_table(fm_results_mean_n[0], bold_rows = False)
# Out:
# Mean N - full sample
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &               IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.09737 &         0.08263 &         0.07943 &          0.13792 &                         0.06596 &          0.06523 &          0.06397 &          0.06403 \\
#                                           &                                          (1.15670) &       (1.04010) &       (1.04930) &    (1.31852) (*) &                       (0.96958) &        (0.98473) &        (0.97868) &        (0.97917) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.03648 &         0.05179 &         0.05499 &         -0.00428 &                         0.07225 &          0.07212 &          0.07375 &          0.07436 \\
#                                           &                                          (0.38953) &       (0.56846) &       (0.62268) &       (-0.03755) &                       (0.86311) &        (0.87005) &        (0.89154) &        (0.91115) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.01707 &        -0.01987 &        -0.01988 &         -0.01432 &                        -0.00390 &         -0.00582 &         -0.00521 &         -0.00703 \\
#                                           &                                         (-0.65336) &      (-0.75671) &      (-0.75597) &       (-0.54115) &                      (-0.09785) &       (-0.15151) &       (-0.12996) &       (-0.18488) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.03497 &        -0.03516 &        -0.03399 &         -0.04049 &                        -0.03619 &         -0.03679 &         -0.03811 &         -0.03885 \\
#                                           &                                     (-1.35501) (*) &  (-1.34783) (*) &  (-1.30515) (*) &   (-1.57201) (*) &                      (-1.14028) &       (-1.16503) &       (-1.22346) &       (-1.22406) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.09101 &         0.16079 &         0.16218 &          0.10839 &                         0.29647 &          0.29617 &          0.29558 &          0.29489 \\
#                                           &                                          (0.53281) &       (1.08592) &       (1.11414) &        (0.57642) &                 (2.61761) (***) &  (2.60797) (***) &  (2.67517) (***) &  (2.58079) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                           -0.19869 &                 &                 &                  &                        -0.02215 &                  &                  &                  \\
#                                           &                                     (-1.38720) (*) &                 &                 &                  &                      (-0.22419) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &         0.08402 &                 &                  &                                 &         -0.03946 &                  &                  \\
#                                           &                                                    &       (0.86747) &                 &                  &                                 &       (-0.54899) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &        -0.02733 &                  &                                 &                  &          0.00079 &                  \\
#                                           &                                                    &                 &      (-0.20156) &                  &                                 &                  &        (0.00666) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &         -0.44400 &                                 &                  &                  &         -0.03049 \\
#                                           &                                                    &                 &                 &  (-2.09214) (**) &                                 &                  &                  &       (-0.26402) \\
# $R^2$                                        &                                            0.53963 &         0.49131 &         0.48050 &          0.77320 &                         0.86985 &          0.87318 &          0.86886 &          0.87085 \\
# $N$                                          &                                               2491 &            2491 &            2491 &             2491 &                            2491 &             2491 &             2491 &             2491 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %%
print("Sum - Forward \n\n")

print_latex_table(fm_results_forward_sum[0], bold_rows = False)
# Out:
# Sum - Forward
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &              IV &                               I &              II &             III &              IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.03757 &         0.07802 &         0.03335 &         0.04552 &                         0.07315 &         0.07090 &         0.06518 &         0.09072 \\
#                                           &                                          (0.44186) &       (0.86773) &       (0.37668) &       (0.53220) &                       (0.89825) &       (0.92919) &       (0.86426) &       (1.08107) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.07712 &         0.03331 &         0.08031 &         0.06851 &                         0.04016 &         0.03916 &         0.04626 &         0.02162 \\
#                                           &                                          (0.75371) &       (0.31953) &       (0.76690) &       (0.68595) &                       (0.42018) &       (0.42138) &       (0.49852) &       (0.21870) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.05083 &        -0.04771 &        -0.04770 &        -0.05080 &                        -0.03455 &        -0.03658 &        -0.03573 &        -0.03723 \\
#                                           &                                     (-1.42827) (*) &  (-1.35470) (*) &  (-1.36220) (*) &  (-1.42651) (*) &                      (-0.66961) &      (-0.72288) &      (-0.69582) &      (-0.72581) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.04736 &        -0.04270 &        -0.05035 &        -0.04541 &                        -0.06231 &        -0.06496 &        -0.07263 &        -0.06893 \\
#                                           &                                         (-1.27411) &      (-1.14178) &  (-1.35837) (*) &      (-1.22828) &                  (-1.38526) (*) &  (-1.44697) (*) &  (-1.61842) (*) &  (-1.51601) (*) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.17919 &         0.17200 &         0.17425 &         0.19138 &                         0.17447 &         0.17431 &         0.16950 &         0.17856 \\
#                                           &                                      (1.56629) (*) &   (1.34636) (*) &   (1.52444) (*) &  (1.67069) (**) &                   (1.44974) (*) &   (1.49943) (*) &   (1.45060) (*) &   (1.53675) (*) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                            1.06156 &                 &                 &                 &                        -0.88975 &                 &                 &                 \\
#                                           &                                          (0.91575) &                 &                 &                 &                      (-1.03223) &                 &                 &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &         1.03821 &                 &                 &                                 &        -0.42517 &                 &                 \\
#                                           &                                                    &       (1.22326) &                 &                 &                                 &      (-0.87217) &                 &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &         1.00629 &                 &                                 &                 &        -0.28368 &                 \\
#                                           &                                                    &                 &       (1.17841) &                 &                                 &                 &      (-0.42870) &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &        -0.88077 &                                 &                 &                 &        -0.54119 \\
#                                           &                                                    &                 &                 &      (-1.23700) &                                 &                 &                 &      (-0.79096) \\
# $R^2$                                        &                                            0.74374 &         0.78065 &         0.79461 &         0.76408 &                         0.75895 &         0.73394 &         0.72413 &         0.73219 \\
# $N$                                          &                                               1438 &            1438 &            1438 &            1438 &                            1438 &            1438 &            1438 &            1438 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %%
print("Mean N - Forward \n\n")

print_latex_table(fm_results_forward_mean_n[0], bold_rows = False)
# Out:
# Mean N - Forward
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &               IV &                               I &              II &             III &              IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.03578 &         0.05446 &         0.03397 &          0.07316 &                         0.06743 &         0.06950 &         0.07373 &         0.08532 \\
#                                           &                                          (0.45274) &       (0.66975) &       (0.43503) &        (0.83492) &                       (0.86295) &       (0.90907) &       (0.93930) &       (1.03261) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.07821 &         0.05892 &         0.07993 &          0.03958 &                         0.04681 &         0.04037 &         0.03700 &         0.02883 \\
#                                           &                                          (0.82172) &       (0.60136) &       (0.84752) &        (0.38780) &                       (0.50910) &       (0.43097) &       (0.38993) &       (0.30088) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.05040 &        -0.05062 &        -0.05051 &         -0.04857 &                        -0.04027 &        -0.03798 &        -0.03539 &        -0.04352 \\
#                                           &                                     (-1.43033) (*) &  (-1.42174) (*) &  (-1.42297) (*) &   (-1.36401) (*) &                      (-0.78813) &      (-0.75502) &      (-0.68383) &      (-0.85186) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.04406 &        -0.04476 &        -0.04372 &         -0.04720 &                        -0.05711 &        -0.06782 &        -0.07280 &        -0.06708 \\
#                                           &                                         (-1.18602) &      (-1.20018) &      (-1.17564) &       (-1.27588) &                      (-1.25989) &  (-1.51734) (*) &  (-1.62450) (*) &  (-1.48435) (*) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.16757 &         0.15791 &         0.16676 &          0.17592 &                         0.16580 &         0.17450 &         0.16679 &         0.17610 \\
#                                           &                                      (1.52032) (*) &   (1.30308) (*) &   (1.50495) (*) &    (1.48648) (*) &                   (1.36976) (*) &   (1.50983) (*) &   (1.51664) (*) &   (1.49149) (*) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                           -0.03124 &                 &                 &                  &                        -0.11320 &                 &                 &                 \\
#                                           &                                         (-0.23795) &                 &                 &                  &                      (-1.02058) &                 &                 &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &         0.15741 &                 &                  &                                 &        -0.04757 &                 &                 \\
#                                           &                                                    &   (1.36391) (*) &                 &                  &                                 &      (-0.56154) &                 &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &        -0.03071 &                  &                                 &                 &        -0.02857 &                 \\
#                                           &                                                    &                 &      (-0.17744) &                  &                                 &                 &      (-0.24996) &                 \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &         -0.25414 &                                 &                 &                 &        -0.12132 \\
#                                           &                                                    &                 &                 &  (-1.72675) (**) &                                 &                 &                 &      (-1.00244) \\
# $R^2$                                        &                                            0.73240 &         0.75448 &         0.73206 &          0.80320 &                         0.76174 &         0.72568 &         0.72036 &         0.76650 \\
# $N$                                          &                                               1438 &            1438 &            1438 &             1438 &                            1438 &            1438 &            1438 &            1438 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %%
print("Sum - Backward \n\n")

print_latex_table(fm_results_backward_sum[0], bold_rows = False)
# Out:
# Sum - Backward
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &          II &         III &          IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.08521 &     0.09646 &     0.10811 &     0.12013 &                         0.17827 &          0.14360 &          0.11740 &          0.14088 \\
#                                           &                                          (0.66513) &   (0.80509) &   (0.91203) &   (0.93852) &                   (1.49970) (*) &    (1.33613) (*) &        (1.08011) &        (1.21741) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.07508 &     0.06510 &     0.05277 &     0.04282 &                        -0.01468 &          0.02058 &          0.04782 &          0.02406 \\
#                                           &                                          (0.46131) &   (0.41788) &   (0.34497) &   (0.26276) &                      (-0.09493) &        (0.14160) &        (0.32667) &        (0.15765) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                            0.02592 &     0.02637 &     0.02739 &     0.02736 &                         0.04072 &          0.02834 &          0.01511 &          0.02391 \\
#                                           &                                          (0.67039) &   (0.67874) &   (0.70814) &   (0.70700) &                       (0.65819) &        (0.46794) &        (0.24640) &        (0.39043) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.02566 &    -0.02675 &    -0.02468 &    -0.02955 &                         0.02207 &          0.02367 &          0.03048 &          0.02519 \\
#                                           &                                         (-0.73215) &  (-0.76878) &  (-0.71216) &  (-0.84852) &                       (0.47755) &        (0.52129) &        (0.67917) &        (0.53688) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.14481 &     0.15131 &     0.13869 &     0.13238 &                         0.44813 &          0.45041 &          0.43833 &          0.44908 \\
#                                           &                                          (1.12376) &   (1.21973) &   (1.21376) &   (1.05324) &                 (3.69590) (***) &  (3.71312) (***) &  (3.64809) (***) &  (3.66077) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                            0.95361 &             &             &             &                        -0.77718 &                  &                  &                  \\
#                                           &                                          (1.17510) &             &             &             &                      (-1.13542) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &     0.14582 &             &             &                                 &         -0.22307 &                  &                  \\
#                                           &                                                    &   (0.19469) &             &             &                                 &       (-0.51052) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &             &    -0.16709 &             &                                 &                  &          0.24348 &                  \\
#                                           &                                                    &             &  (-0.43883) &             &                                 &                  &        (0.83270) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &             &             &    -0.40651 &                                 &                  &                  &          0.12425 \\
#                                           &                                                    &             &             &  (-1.01390) &                                 &                  &                  &        (0.35779) \\
# $R^2$                                        &                                            0.42473 &     0.37770 &     0.38311 &     0.39958 &                         0.59160 &          0.55465 &          0.56913 &          0.55339 \\
# $N$                                          &                                               1053 &        1053 &        1053 &        1053 &                            1053 &             1053 &             1053 &             1053 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %%
print("Mean N - Backward \n\n")

print_latex_table(fm_results_backward_mean_n[0], bold_rows = False)
# Out:
# Mean N - Backward
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &          II &         III &          IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.08143 &     0.06619 &     0.09853 &     0.12769 &                         0.15870 &          0.13910 &          0.09740 &          0.11040 \\
#                                           &                                          (0.57729) &   (0.48742) &   (0.84060) &   (0.96019) &                   (1.41988) (*) &        (1.25416) &        (0.89367) &        (1.02637) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.07731 &     0.09406 &     0.06347 &     0.03683 &                         0.00445 &          0.02526 &          0.06920 &          0.05271 \\
#                                           &                                          (0.44669) &   (0.55685) &   (0.41587) &   (0.22006) &                       (0.02971) &        (0.16995) &        (0.47490) &        (0.36334) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                            0.02554 &     0.02880 &     0.02552 &     0.02638 &                         0.03709 &          0.02400 &          0.00378 &          0.02022 \\
#                                           &                                          (0.66093) &   (0.74408) &   (0.66049) &   (0.68101) &                       (0.61296) &        (0.40027) &        (0.06028) &        (0.33795) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.02373 &    -0.02742 &    -0.02666 &    -0.02861 &                         0.02653 &          0.02192 &          0.03515 &          0.02038 \\
#                                           &                                         (-0.67355) &  (-0.77456) &  (-0.76886) &  (-0.82749) &                       (0.57841) &        (0.48609) &        (0.76845) &        (0.44903) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.19213 &     0.13430 &     0.15032 &     0.13232 &                         0.45938 &          0.45430 &          0.40374 &          0.45489 \\
#                                           &                                      (1.29925) (*) &   (1.06179) &   (1.23565) &   (1.06359) &                 (3.76931) (***) &  (3.71097) (***) &  (3.42056) (***) &  (3.75820) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                            0.15828 &             &             &             &                        -0.06180 &                  &                  &                  \\
#                                           &                                     (1.69959) (**) &             &             &             &                      (-0.91269) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &     0.12760 &             &             &                                 &         -0.03187 &                  &                  \\
#                                           &                                                    &   (1.14221) &             &             &                                 &       (-0.51220) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &             &     0.01379 &             &                                 &                  &          0.12813 &                  \\
#                                           &                                                    &             &   (0.13935) &             &                                 &                  &        (1.22097) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &             &             &    -0.13442 &                                 &                  &                  &         -0.07234 \\
#                                           &                                                    &             &             &  (-1.13688) &                                 &                  &                  &       (-0.78724) \\
# $R^2$                                        &                                            0.50958 &     0.44614 &     0.37717 &     0.40934 &                         0.56849 &          0.55453 &          0.60477 &          0.56041 \\
# $N$                                          &                                               1053 &        1053 &        1053 &        1053 &                            1053 &             1053 &             1053 &             1053 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %% [markdown]
# # Robustness check - Positive vs. Negative sentiment

# %% [markdown]
# # Unexpected climate change
# This script generates the measure of unexpected climate change perception using AR(1) model

# %%
# Loading in Twitter data
df = read_db(engine=engine, statement="select * from twitter_kaggle")

# Setting datetime (potentially, we should deal with time-zones problems)
df["datetime"] = pd.to_datetime(df["created_at"])
df = df.set_index(df["datetime"], drop=True)  # Setting index
df.index.name = None

df = df.drop(columns=["created_at", "datetime"]) # dropping irrelevant colunms

# %%
df_pos = df.loc[df['sentiment'] > 0]
df_neg = df.loc[df['sentiment'] < 0]

df = None

# %%
def create_daily_sum(dataframe):

    # will be overwritten in loop
    topic = "aggregate"

    daily_sum = transform(dataframe, transform_type="sum", mapping="log", topic=topic)
    daily_sum = pd.merge(
        left=daily_sum,
        right=forecast_residual(
            daily_sum[f"{topic}_transformed"],
            return_spec_test=True,
            auto_lag=True,
        ),
        how="left",
        left_index=True,
        right_index=True,
    )


    for topic in dataframe["topic"].unique():
        daily_topic_sum = transform(dataframe, transform_type="sum", mapping="log", topic=topic)

        daily_topic_sum = pd.merge(
            left=daily_topic_sum,
            right=forecast_residual(
                daily_topic_sum[f"{topic}_transformed"],
                return_spec_test=True,
                auto_lag=True,
            ),
            left_index=True,
            right_index=True,
            how="left",
        )

        daily_sum = pd.merge(
            left=daily_sum,
            right=daily_topic_sum,
            how="left",
            left_index=True,
            right_index=True,
        )

    daily_sum.columns = daily_sum.columns.map(
        lambda x: x.lower().replace("/ ", "").replace(" ", "_")
    )

    return daily_sum

# %%
df_pos = create_daily_sum(df_pos)
df_neg = create_daily_sum(df_neg)

# %%
factors_pos = pd.merge(left=factors, right=df_pos, left_index=True, right_index=True)
factors_neg = pd.merge(left=factors, right=df_neg, left_index=True, right_index=True)

# %%
# annualise factors
for factor in BASE_AP_MODEL:
    factors_pos[factor] = factors_pos[factor] * YEARLY_BUSINESS_DAYS
    factors_neg[factor] = factors_neg[factor] * YEARLY_BUSINESS_DAYS

# %%
# remove weekends and holidays from factors
factors_pos = factors_pos.reindex(returns_bm_size.index).dropna(how="all")
factors_neg = factors_neg.reindex(returns_bm_size.index).dropna(how="all")

# select factor observations
factors_pos = factors_pos.loc[START_DATE:END_DATE]
factors_neg = factors_neg.loc[START_DATE:END_DATE]

# %%
fm_results_pos = generate_fm_results(
    factors_pos, returns, portfolios=["bm_size", "49_industries"]
)
fm_results_neg = generate_fm_results(
    factors_neg, returns, portfolios=["bm_size", "49_industries"]
)
# Out:
# 100%|██████████| 2/2 [05:10<00:00, 155.45s/it]
# 100%|██████████| 2/2 [05:13<00:00, 156.55s/it]

# %%
print("Positive")
display(fm_results_pos[0])

print("Negative")
display(fm_results_neg[0])
# Out:
# Positive
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.060112     0.074004
# t_c                                                    0.728784     0.933810
# mkt-rf                                                 0.072867     0.059049
# t_mkt-rf                                               0.783010     0.648274
# smb                                                   -0.019548    -0.019078
# t_smb                                                 -0.747360    -0.734313
# hml                                                   -0.034215    -0.034058
# t_hml                                                 -1.320085    -1.310217
# mom                                                    0.133346     0.154697
# t_mom                                                  0.910710     1.059022
# aggregate_transformed_residuals                       -0.297426          NaN
# t_aggregate_transformed_residuals                     -1.032691          NaN
# weather_extremes_transformed_residuals                      NaN    -0.200982
# t_weather_extremes_transformed_residuals                    NaN    -0.933232
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.499889     0.495943
# nobs                                                2491.000000  2491.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.067651     0.067771
# t_c                                                    0.857178     0.827510
# mkt-rf                                                 0.065004     0.065282
# t_mkt-rf                                               0.721289     0.705750
# smb                                                   -0.019467    -0.013289
# t_smb                                                 -0.745643    -0.502943
# hml                                                   -0.034528    -0.030619
# t_hml                                                 -1.330943    -1.183637
# mom                                                    0.126738     0.059831
# t_mom                                                  0.874581     0.391225
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...    -0.218179          NaN
# t_importance_of_human_intervantion_transformed_...    -0.933666          NaN
# politics_transformed_residuals                              NaN    -0.355871
# t_politics_transformed_residuals                            NaN    -1.447380
# r2                                                     0.497501     0.499507
# nobs                                                2491.000000  2461.000000
#
#                                                     I:49_industries  \
# c                                                          0.072113
# t_c                                                        1.091145
# mkt-rf                                                     0.065705
# t_mkt-rf                                                   0.796504
# smb                                                       -0.002944
# t_smb                                                     -0.076169
# hml                                                       -0.037615
# t_hml                                                     -1.191141
# mom                                                        0.291661
# t_mom                                                      2.549332
# aggregate_transformed_residuals                            0.066888
# t_aggregate_transformed_residuals                          0.288370
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.870749
# nobs                                                    2491.000000
#
#                                                     II:49_industries  \
# c                                                           0.068133
# t_c                                                         1.014862
# mkt-rf                                                      0.069813
# t_mkt-rf                                                    0.835732
# smb                                                        -0.003578
# t_smb                                                      -0.091638
# hml                                                        -0.038231
# t_hml                                                      -1.212632
# mom                                                         0.294993
# t_mom                                                       2.590134
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                      0.042760
# t_weather_extremes_transformed_residuals                    0.259049
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.869776
# nobs                                                     2491.000000
#
#                                                     III:49_industries  \
# c                                                            0.079790
# t_c                                                          1.217983
# mkt-rf                                                       0.058287
# t_mkt-rf                                                     0.711899
# smb                                                         -0.005585
# t_smb                                                       -0.145059
# hml                                                         -0.036617
# t_hml                                                       -1.148425
# mom                                                          0.276439
# t_mom                                                        2.425294
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...           0.108824
# t_importance_of_human_intervantion_transformed_...           0.499453
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.874554
# nobs                                                      2491.000000
#
#                                                     IV:49_industries
# c                                                           0.067289
# t_c                                                         0.972084
# mkt-rf                                                      0.070920
# t_mkt-rf                                                    0.830099
# smb                                                         0.004894
# t_smb                                                       0.127837
# hml                                                        -0.034485
# t_hml                                                      -1.077396
# mom                                                         0.308165
# t_mom                                                       2.682430
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                              0.038892
# t_politics_transformed_residuals                            0.185924
# r2                                                          0.882740
# nobs                                                     2461.000000
# Negative
#                                                       I:bm_size   II:bm_size  \
# c                                                      0.066165     0.067688
# t_c                                                    0.807229     0.822134
# mkt-rf                                                 0.067792     0.064973
# t_mkt-rf                                               0.735573     0.688588
# smb                                                   -0.020146    -0.018910
# t_smb                                                 -0.768773    -0.724010
# hml                                                   -0.034229    -0.034863
# t_hml                                                 -1.317116    -1.335795
# mom                                                    0.154819     0.155607
# t_mom                                                  1.096631     1.027601
# aggregate_transformed_residuals                        0.146839          NaN
# t_aggregate_transformed_residuals                      0.505064          NaN
# weather_extremes_transformed_residuals                      NaN     0.328140
# t_weather_extremes_transformed_residuals                    NaN     1.285910
# importance_of_human_intervantion_transformed_re...          NaN          NaN
# t_importance_of_human_intervantion_transformed_...          NaN          NaN
# politics_transformed_residuals                              NaN          NaN
# t_politics_transformed_residuals                            NaN          NaN
# r2                                                     0.485243     0.510776
# nobs                                                2491.000000  2491.000000
#
#                                                     III:bm_size   IV:bm_size  \
# c                                                      0.070787     0.090983
# t_c                                                    0.862905     1.041051
# mkt-rf                                                 0.063496     0.043962
# t_mkt-rf                                               0.685022     0.452129
# smb                                                   -0.020393    -0.017724
# t_smb                                                 -0.775814    -0.677647
# hml                                                   -0.034479    -0.035730
# t_hml                                                 -1.321875    -1.367807
# mom                                                    0.161081     0.245942
# t_mom                                                  1.147672     1.604677
# aggregate_transformed_residuals                             NaN          NaN
# t_aggregate_transformed_residuals                           NaN          NaN
# weather_extremes_transformed_residuals                      NaN          NaN
# t_weather_extremes_transformed_residuals                    NaN          NaN
# importance_of_human_intervantion_transformed_re...     0.061382          NaN
# t_importance_of_human_intervantion_transformed_...     0.257215          NaN
# politics_transformed_residuals                              NaN    -0.319644
# t_politics_transformed_residuals                            NaN    -1.102335
# r2                                                     0.481083     0.538612
# nobs                                                2491.000000  2491.000000
#
#                                                     I:49_industries  \
# c                                                          0.072057
# t_c                                                        1.084525
# mkt-rf                                                     0.065945
# t_mkt-rf                                                   0.796675
# smb                                                       -0.002925
# t_smb                                                     -0.075465
# hml                                                       -0.036902
# t_hml                                                     -1.166639
# mom                                                        0.293561
# t_mom                                                      2.573721
# aggregate_transformed_residuals                           -0.071648
# t_aggregate_transformed_residuals                         -0.313739
# weather_extremes_transformed_residuals                          NaN
# t_weather_extremes_transformed_residuals                        NaN
# importance_of_human_intervantion_transformed_re...              NaN
# t_importance_of_human_intervantion_transformed_...              NaN
# politics_transformed_residuals                                  NaN
# t_politics_transformed_residuals                                NaN
# r2                                                         0.870920
# nobs                                                    2491.000000
#
#                                                     II:49_industries  \
# c                                                           0.073807
# t_c                                                         1.090809
# mkt-rf                                                      0.064296
# t_mkt-rf                                                    0.767779
# smb                                                        -0.002248
# t_smb                                                      -0.057398
# hml                                                        -0.037479
# t_hml                                                      -1.189271
# mom                                                         0.293364
# t_mom                                                       2.550144
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                     -0.111674
# t_weather_extremes_transformed_residuals                   -0.588167
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                                   NaN
# t_politics_transformed_residuals                                 NaN
# r2                                                          0.874904
# nobs                                                     2491.000000
#
#                                                     III:49_industries  \
# c                                                            0.081850
# t_c                                                          1.212044
# mkt-rf                                                       0.056756
# t_mkt-rf                                                     0.680673
# smb                                                         -0.001023
# t_smb                                                       -0.026365
# hml                                                         -0.036479
# t_hml                                                       -1.144696
# mom                                                          0.284347
# t_mom                                                        2.539154
# aggregate_transformed_residuals                                   NaN
# t_aggregate_transformed_residuals                                 NaN
# weather_extremes_transformed_residuals                            NaN
# t_weather_extremes_transformed_residuals                          NaN
# importance_of_human_intervantion_transformed_re...          -0.107623
# t_importance_of_human_intervantion_transformed_...          -0.448110
# politics_transformed_residuals                                    NaN
# t_politics_transformed_residuals                                  NaN
# r2                                                           0.874452
# nobs                                                      2491.000000
#
#                                                     IV:49_industries
# c                                                           0.074677
# t_c                                                         1.108364
# mkt-rf                                                      0.065065
# t_mkt-rf                                                    0.779423
# smb                                                        -0.014811
# t_smb                                                      -0.382045
# hml                                                        -0.038277
# t_hml                                                      -1.202531
# mom                                                         0.291259
# t_mom                                                       2.551646
# aggregate_transformed_residuals                                  NaN
# t_aggregate_transformed_residuals                                NaN
# weather_extremes_transformed_residuals                           NaN
# t_weather_extremes_transformed_residuals                         NaN
# importance_of_human_intervantion_transformed_re...               NaN
# t_importance_of_human_intervantion_transformed_...               NaN
# politics_transformed_residuals                             -0.184540
# t_politics_transformed_residuals                           -0.855279
# r2                                                          0.881284
# nobs                                                     2491.000000

# %%
print("Positive - full sample \n\n")

print_latex_table(fm_results_pos[0], bold_rows = False)
# Out:
# Positive - full sample
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &              IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.06011 &         0.07400 &         0.06765 &         0.06777 &                         0.07211 &          0.06813 &          0.07979 &          0.06729 \\
#                                           &                                          (0.72878) &       (0.93381) &       (0.85718) &       (0.82751) &                       (1.09114) &        (1.01486) &        (1.21798) &        (0.97208) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.07287 &         0.05905 &         0.06500 &         0.06528 &                         0.06570 &          0.06981 &          0.05829 &          0.07092 \\
#                                           &                                          (0.78301) &       (0.64827) &       (0.72129) &       (0.70575) &                       (0.79650) &        (0.83573) &        (0.71190) &        (0.83010) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.01955 &        -0.01908 &        -0.01947 &        -0.01329 &                        -0.00294 &         -0.00358 &         -0.00559 &          0.00489 \\
#                                           &                                         (-0.74736) &      (-0.73431) &      (-0.74564) &      (-0.50294) &                      (-0.07617) &       (-0.09164) &       (-0.14506) &        (0.12784) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.03421 &        -0.03406 &        -0.03453 &        -0.03062 &                        -0.03762 &         -0.03823 &         -0.03662 &         -0.03448 \\
#                                           &                                     (-1.32008) (*) &  (-1.31022) (*) &  (-1.33094) (*) &      (-1.18364) &                      (-1.19114) &       (-1.21263) &       (-1.14843) &       (-1.07740) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.13335 &         0.15470 &         0.12674 &         0.05983 &                         0.29166 &          0.29499 &          0.27644 &          0.30817 \\
#                                           &                                          (0.91071) &       (1.05902) &       (0.87458) &       (0.39122) &                 (2.54933) (***) &  (2.59013) (***) &  (2.42529) (***) &  (2.68243) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                           -0.29743 &                 &                 &                 &                         0.06689 &                  &                  &                  \\
#                                           &                                         (-1.03269) &                 &                 &                 &                       (0.28837) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &        -0.20098 &                 &                 &                                 &          0.04276 &                  &                  \\
#                                           &                                                    &      (-0.93323) &                 &                 &                                 &        (0.25905) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &        -0.21818 &                 &                                 &                  &          0.10882 &                  \\
#                                           &                                                    &                 &      (-0.93367) &                 &                                 &                  &        (0.49945) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &        -0.35587 &                                 &                  &                  &          0.03889 \\
#                                           &                                                    &                 &                 &  (-1.44738) (*) &                                 &                  &                  &        (0.18592) \\
# $R^2$                                        &                                            0.49989 &         0.49594 &         0.49750 &         0.49951 &                         0.87075 &          0.86978 &          0.87455 &          0.88274 \\
# $N$                                          &                                               2491 &            2491 &            2491 &            2461 &                            2491 &             2491 &             2491 &             2461 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(

# %%
print("Negative - full sample \n\n")

print_latex_table(fm_results_neg[0], bold_rows = False)
# Out:
# Negative - full sample
#
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lllllllll}
#
# {} & \multicolumn{4}{c}{\textbf{25 Book-to-Market and Size Sorted Portfolios}} & \multicolumn{4}{c}{\textbf{49 Industry Portfolios}} \\
# {} &                                                     I &              II &             III &              IV &                               I &               II &              III &               IV \\
#
# \multirow{2}{*}{$\widehat{\gamma_{0}}$}      &                                            0.06616 &         0.06769 &         0.07079 &         0.09098 &                         0.07206 &          0.07381 &          0.08185 &          0.07468 \\
#                                           &                                          (0.80723) &       (0.82213) &       (0.86291) &       (1.04105) &                       (1.08453) &        (1.09081) &        (1.21204) &        (1.10836) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mkt-rf}$} &                                            0.06779 &         0.06497 &         0.06350 &         0.04396 &                         0.06594 &          0.06430 &          0.05676 &          0.06506 \\
#                                           &                                          (0.73557) &       (0.68859) &       (0.68502) &       (0.45213) &                       (0.79667) &        (0.76778) &        (0.68067) &        (0.77942) \\
# \multirow{2}{*}{$\widehat{\gamma}_{smb}$}    &                                           -0.02015 &        -0.01891 &        -0.02039 &        -0.01772 &                        -0.00293 &         -0.00225 &         -0.00102 &         -0.01481 \\
#                                           &                                         (-0.76877) &      (-0.72401) &      (-0.77581) &      (-0.67765) &                      (-0.07546) &       (-0.05740) &       (-0.02636) &       (-0.38205) \\
# \multirow{2}{*}{$\widehat{\gamma}_{hml}$}    &                                           -0.03423 &        -0.03486 &        -0.03448 &        -0.03573 &                        -0.03690 &         -0.03748 &         -0.03648 &         -0.03828 \\
#                                           &                                     (-1.31712) (*) &  (-1.33580) (*) &  (-1.32188) (*) &  (-1.36781) (*) &                      (-1.16664) &       (-1.18927) &       (-1.14470) &       (-1.20253) \\
# \multirow{2}{*}{$\widehat{\gamma}_{mom}$}    &                                            0.15482 &         0.15561 &         0.16108 &         0.24594 &                         0.29356 &          0.29336 &          0.28435 &          0.29126 \\
#                                           &                                          (1.09663) &       (1.02760) &       (1.14767) &   (1.60468) (*) &                 (2.57372) (***) &  (2.55014) (***) &  (2.53915) (***) &  (2.55165) (***) \\
# \multirow{2}{*}{$\widehat{\gamma}_{agg}$}    &                                            0.14684 &                 &                 &                 &                        -0.07165 &                  &                  &                  \\
#                                           &                                          (0.50506) &                 &                 &                 &                      (-0.31374) &                  &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{wea}$}    &                                                    &         0.32814 &                 &                 &                                 &         -0.11167 &                  &                  \\
#                                           &                                                    &   (1.28591) (*) &                 &                 &                                 &       (-0.58817) &                  &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{imp}$}    &                                                    &                 &         0.06138 &                 &                                 &                  &         -0.10762 &                  \\
#                                           &                                                    &                 &       (0.25722) &                 &                                 &                  &       (-0.44811) &                  \\
# \multirow{2}{*}{$\widehat{\gamma}_{pol}$}    &                                                    &                 &                 &        -0.31964 &                                 &                  &                  &         -0.18454 \\
#                                           &                                                    &                 &                 &      (-1.10233) &                                 &                  &                  &       (-0.85528) \\
# $R^2$                                        &                                            0.48524 &         0.51078 &         0.48108 &         0.53861 &                         0.87092 &          0.87490 &          0.87445 &          0.88128 \\
# $N$                                          &                                               2491 &            2491 &            2491 &            2491 &                            2491 &             2491 &             2491 &             2491 \\
#
# \end{tabular}
# \end{table}
# /var/folders/3b/lkjl6nz51lb5h1pjxb6ljm6r0000gn/T/ipykernel_21295/1471699064.py:90: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = print_df.to_latex(
